# %%
# !pip install datasets transformers --quiet
# !pip install -U datasets huggingface_hub fsspec
# !pip install captum
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.33.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (2025.3.0)
# Collecting fsspec
#   Using cached fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub) (1.1.5)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: captum in /usr/local/lib/python3.11/dist-packages (0.8.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from captum) (3.10.0)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.11/dist-packages (from captum) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from captum) (24.2)
# Requirement already satisfied: torch>=1.10 in /usr/local/lib/python3.11/dist-packages (from captum) (2.6.0+cu124)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from captum) (4.67.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.10->captum) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.10->captum) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->captum) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.10->captum) (3.0.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
from datasets import load_dataset
from sklearn.metrics import roc_auc_score
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import os
from tqdm.notebook import tqdm

# %%
eraser = load_dataset("movie_rationales")
eraser_train = eraser["train"]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# movie_rationales.py: 0.00B [00:00, ?B/s]
# The repository for movie_rationales contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/movie_rationales.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# Downloading data:   0%|          | 0.00/3.90M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1600 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/200 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/199 [00:00<?, ? examples/s]

# %%
def find_token_spans(text, evidence_list, tokenizer):
    encoding = tokenizer(text, return_offsets_mapping=True, return_tensors="pt", truncation=True)
    offsets = encoding["offset_mapping"][0].tolist()
    spans = []

    for phrase in evidence_list:
        start_char = text.find(phrase)
        if start_char == -1:
            continue
        end_char = start_char + len(phrase)

        span_tokens = []
        for idx, (tok_start, tok_end) in enumerate(offsets):
            if tok_start is None or tok_end is None:
                continue
            if tok_start < end_char and tok_end > start_char:
                span_tokens.append(idx)
        if span_tokens:
            spans.append((span_tokens[0], span_tokens[-1] + 1))
    return spans

def get_relevant_positions(spans, token_positions):
    relevant = []
    for pos in token_positions:
        for span_low, span_high in spans:
            if span_low <= pos and span_high >= pos:
                relevant.append(pos)
    return relevant

def precision(spans, token_positions):
    relevant = get_relevant_positions(spans, token_positions)
    return len(relevant) / len(token_positions)

def weight_recall(spans, weights, token_positions):
    relevant = get_relevant_positions(spans, token_positions)
    mask = np.isin(token_positions, relevant)
    relevant_weights = np.abs(weights[mask])
    return np.sum(relevant_weights)/np.sum(np.abs(weights)) if sum(np.abs(weights)) > 0 else 0.0


def jaccard_similarity(spans, token_positions):
    gold_token_set = set()
    for start, end in spans:
        gold_token_set.update(range(start, end))

    pred_token_set = set(token_positions)

    intersection = gold_token_set & pred_token_set
    union = gold_token_set | pred_token_set

    return len(intersection) / len(union) if union else 0.0

def span_hit_recall(spans, token_positions, k=5):
    hits = 0
    pred_token_set = set(token_positions)

    for start, end in spans:
        span_tokens = set(range(start, end))
        if span_tokens & pred_token_set:
            hits += 1

    return min(k, hits) / min(k, len(spans)) if spans else 0.0

def f1_token(spans, weights, token_positions):
    p = precision(spans, token_positions)
    r = weight_recall(spans, weights, token_positions)
    return 2 * p * r / (p + r) if (p + r) > 0 else 0.0

# %%
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
perturbation_folder = "/content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation"
gradient_folder = "/content/drive/MyDrive/NLP_project/bert_eraser/results/gradient"
linear_folder = "/content/drive/MyDrive/NLP_project/bert_eraser/results/linear"
ext = '.parquet'

tokenizer = AutoTokenizer.from_pretrained(model_name)
batch_size = 10

for batch_start in tqdm(range(0, len(eraser_train), batch_size)):
    file_name = f'/batch_{batch_start}'
    evidence_batch = eraser_train['evidences'][batch_start: batch_start + batch_size]

    for current_folder in [perturbation_folder, gradient_folder, linear_folder]:
        save_path = current_folder + file_name + '_metrics' + ext

        if os.path.exists(save_path):
            print(f"Skipping {save_path}, already exists.")
            continue

        current_batch = pd.read_parquet(current_folder + file_name + ext)

        precisions = []
        weight_recalls = []
        f1_tokens = []
        jaccards = []
        span_hit_recalls = []

        for i in range(batch_size):
            text = current_batch['text'][i]
            evidence = evidence_batch[i]
            spans = find_token_spans(text=text, evidence_list=evidence, tokenizer=tokenizer)
            token_positions = current_batch['token_positions'][i]
            weights = current_batch['weights'][i]

            precision_ = precision(spans, token_positions)
            weight_recall_ = weight_recall(spans, weights, token_positions)
            f1_ = f1_token(spans, weights, token_positions)
            jaccard_ = jaccard_similarity(spans, token_positions)
            span_hit_ = span_hit_recall(spans, token_positions)

            precisions.append(precision_)
            weight_recalls.append(weight_recall_)
            f1_tokens.append(f1_)
            jaccards.append(jaccard_)
            span_hit_recalls.append(span_hit_)

        results = pd.DataFrame({
            'precision': precisions,
            'weight_recall': weight_recalls,
            'f1_token': f1_tokens,
            'jaccard_similarity': jaccards,
            'span_hit_recall': span_hit_recalls
        })

        results.to_parquet(save_path)
# Out:
#   0%|          | 0/158 [00:00<?, ?it/s]
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_0_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_0_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_0_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_10_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_10_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_10_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_20_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_20_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_20_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_30_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_30_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_30_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_40_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_40_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_40_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_50_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_50_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_50_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_60_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_60_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_60_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_70_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_70_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_70_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_80_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_80_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_80_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_90_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_90_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_90_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_600_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_600_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_600_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_610_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_610_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_610_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_620_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_620_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_620_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_630_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_630_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_630_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_640_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_640_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_640_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_650_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_650_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_650_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_660_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_660_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_660_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_670_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_670_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_670_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_680_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_680_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_680_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_690_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_690_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_690_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_700_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_700_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_700_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_710_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_710_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_710_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_720_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_720_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_720_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_730_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_730_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_730_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_740_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_740_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_740_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_750_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_750_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_750_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_760_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_760_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_760_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_770_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_770_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_770_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_780_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_780_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_780_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_790_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_790_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_790_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_800_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_800_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_800_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_810_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_810_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_810_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_820_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_820_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_820_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_830_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_830_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_830_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_840_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_840_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_840_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_850_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_850_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_850_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_860_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_860_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_860_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_870_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_870_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_870_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_880_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_880_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_880_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_890_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_890_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_890_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_900_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_900_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_900_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_910_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_910_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_910_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_920_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_920_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_920_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_930_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_930_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_930_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_940_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_940_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_940_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_950_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_950_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_950_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_960_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_960_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_960_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_970_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_970_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_970_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_980_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_980_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_980_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_990_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_990_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_990_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1000_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1000_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1000_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1010_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1010_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1010_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1020_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1020_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1020_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1030_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1030_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1030_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1040_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1040_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1040_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1050_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1050_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1050_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1060_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1060_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1060_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1070_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1070_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1070_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1080_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1080_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1080_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1090_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1090_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1090_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/perturbation/batch_1570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/gradient/batch_1570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/bert_eraser/results/linear/batch_1570_metrics.parquet, already exists.

# %%
results = pd.DataFrame(columns=['precision', 'weight_recall', 'f1_token', 'jaccard_similarity', 'span_hit_recall', 'method'])

for batch_start in range(0, 1580, batch_size):
    file_name = f'/batch_{batch_start}'
    evidence_batch = eraser_train['evidences'][batch_start: batch_start + batch_size]

    for current_folder in [perturbation_folder, gradient_folder, linear_folder]:
        save_path = current_folder + file_name + '_metrics' + ext
        data = pd.read_parquet(save_path)
        data['method'] = current_folder.split('/')[-1]
        results = pd.concat([results, data])
# Out:
# /tmp/ipython-input-8-1827977307.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, data])

# %%
ext = '.parquet'
batch_size = 10

def calculate_metrics_eraser(folder_name, model_name, size):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    perturbation_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/perturbation"
    gradient_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/gradient"
    linear_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/linear"
    # perturbation_folder = "https://drive.google.com/drive/folders/1v_erpcA8H68aCNb_lzMr8kVRgS2nzaUn?usp=sharing" + f'{folder_name}/results/perturbation'
    # gradient_folder = "https://drive.google.com/drive/folders/1v_erpcA8H68aCNb_lzMr8kVRgS2nzaUn?usp=sharing" + f'{folder_name}/results/gradient'
    # linear_folder = "https://drive.google.com/drive/folders/1v_erpcA8H68aCNb_lzMr8kVRgS2nzaUn?usp=sharing" + f'{folder_name}/results/linear'

    batch_size = 10
    ext = '.parquet'

    for batch_start in tqdm(range(0, size, batch_size)):
        file_name = f'/batch_{batch_start}'
        evidence_batch = eraser_train['evidences'][batch_start: batch_start + batch_size]

        for current_folder in [perturbation_folder, gradient_folder, linear_folder]:
            save_path = current_folder + file_name + '_metrics' + ext

            if os.path.exists(save_path):
                print(f"Skipping {save_path}, already exists.")
                continue

            current_batch = pd.read_parquet(current_folder + file_name + ext)

            precisions = []
            weight_recalls = []
            f1_tokens = []
            jaccards = []
            span_hit_recalls = []

            for i in range(batch_size):
                text = current_batch['text'][i]
                evidence = evidence_batch[i]
                spans = find_token_spans(text=text, evidence_list=evidence, tokenizer=tokenizer)
                token_positions = current_batch['token_positions'][i]
                weights = current_batch['weights'][i]

                precision_ = precision(spans, token_positions)
                weight_recall_ = weight_recall(spans, weights, token_positions)
                f1_ = f1_token(spans, weights, token_positions)
                jaccard_ = jaccard_similarity(spans, token_positions)
                span_hit_ = span_hit_recall(spans, token_positions)

                precisions.append(precision_)
                weight_recalls.append(weight_recall_)
                f1_tokens.append(f1_)
                jaccards.append(jaccard_)
                span_hit_recalls.append(span_hit_)

            results = pd.DataFrame({
                'precision': precisions,
                'weight_recall': weight_recalls,
                'f1_token': f1_tokens,
                'jaccard_similarity': jaccards,
                'span_hit_recall': span_hit_recalls
            })

            results.to_parquet(save_path)

def get_results(folder_name, model_name, size):
    perturbation_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/perturbation"
    gradient_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/gradient"
    linear_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/linear"
    results = pd.DataFrame(columns=['precision', 'weight_recall', 'f1_token', 'jaccard_similarity', 'span_hit_recall', 'method'])

    for batch_start in range(0, size, batch_size):
        file_name = f'/batch_{batch_start}'
        evidence_batch = eraser_train['evidences'][batch_start: batch_start + batch_size]

        for current_folder in [perturbation_folder, gradient_folder, linear_folder]:
            save_path = current_folder + file_name + '_metrics' + ext
            data = pd.read_parquet(save_path)
            data['method'] = current_folder.split('/')[-1]
            results = pd.concat([results, data])
    print(model_name, size)
    display(results.groupby('method').agg('mean'))

# %%
folder_name = 'bert_eraser'
model_name = "distilbert-base-uncased-finetuned-sst-2-english"
size = len(eraser_train)

calculate_metrics_eraser(folder_name, model_name, size)

# %%
get_results(folder_name, model_name, size)

# %%
folder_name = 'gpt_eraser'
model_name = "PavanNeerudu/gpt2-finetuned-sst2"
size = len(eraser_train)

calculate_metrics_eraser(folder_name, model_name, size)
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_0_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_0_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_0_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_10_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_10_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_10_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_20_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_20_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_20_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_30_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_30_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_30_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_40_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_40_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_40_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_50_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_50_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_50_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_60_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_60_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_60_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_70_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_70_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_70_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_80_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_80_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_80_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_90_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_90_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_90_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_600_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_600_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_600_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_610_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_610_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_610_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_620_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_620_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_620_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_630_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_630_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_630_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_640_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_640_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_640_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_650_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_650_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_650_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_660_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_660_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_660_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_670_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_670_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_670_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_680_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_680_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_680_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_690_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_690_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_690_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_700_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_700_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_700_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_710_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_710_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_710_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_720_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_720_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_720_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_730_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_730_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_730_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_740_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_740_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_740_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_750_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_750_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_750_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_760_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_760_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_760_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_770_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_770_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_770_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_780_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_780_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_780_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_790_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_790_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_790_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_800_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_800_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_800_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_810_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_810_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_810_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_820_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_820_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_820_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_830_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_830_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_830_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_840_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_840_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_840_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_850_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_850_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_850_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_860_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_860_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_860_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_870_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_870_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_870_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_880_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_880_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_880_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_890_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_890_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_890_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_900_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_900_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_900_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_910_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_910_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_910_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_920_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_920_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_920_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_930_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_930_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_930_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_940_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_940_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_940_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_950_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_950_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_950_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_960_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_960_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_960_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_970_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_970_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_970_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_980_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_980_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_980_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_990_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_990_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_990_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1000_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1000_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1000_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1010_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1010_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1010_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1020_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1020_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1020_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1030_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1030_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1030_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1040_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1040_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1040_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1050_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1050_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1050_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1060_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1060_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1060_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1070_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1070_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1070_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1080_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1080_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1080_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1090_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1090_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1090_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1100_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1110_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1120_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1130_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1140_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1150_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1160_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1170_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1180_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1190_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1200_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1210_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1220_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1230_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1240_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1250_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1260_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1270_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1280_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1290_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1300_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1310_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1320_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1330_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1340_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1350_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1360_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1370_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1380_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1390_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1400_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1410_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1420_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1430_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1440_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1450_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1460_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1470_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1480_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1490_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1500_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1510_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1520_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1530_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1540_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1550_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1560_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1570_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1580_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_1590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/gradient/batch_1590_metrics.parquet, already exists.
# Skipping /content/drive/MyDrive/NLP_project/gpt_eraser/results/linear/batch_1590_metrics.parquet, already exists.

# %%
get_results(folder_name, model_name, size)
# Out:
# /tmp/ipython-input-6-3738202056.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, data])
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-9-2637041381.py in <cell line: 0>()
# ----> 1 get_results(folder_name, model_name, size)
#
# /tmp/ipython-input-6-3738202056.py in get_results(folder_name, model_name, size)
#      72         for current_folder in [perturbation_folder, gradient_folder, linear_folder]:
#      73             save_path = current_folder + file_name + '_metrics' + ext
# ---> 74             data = pd.read_parquet(save_path)
#      75             data['method'] = current_folder.split('/')[-1]
#      76             results = pd.concat([results, data])
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     265             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     266
# --> 267         path_or_handle, handles, filesystem = _get_path_or_handle(
#     268             path,
#     269             filesystem,
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     138         # fsspec resources can also point to directories
#     139         # this branch is used for example when reading from non-fsspec URLs
# --> 140         handles = get_handle(
#     141             path_or_handle, mode, is_text=False, storage_options=storage_options
#     142         )
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/NLP_project/gpt_eraser/results/perturbation/batch_500_metrics.parquet'

# %%
cose = load_dataset("cos_e", "v1.11")['train']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/1.73M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/222k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/9741 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1221 [00:00<?, ? examples/s]
# {'id': '89afdea1d76272fda8e1538a7d3b7a3f',
#  'question': 'A bride and groom are taking care of proposals, what is the likely ceremony?',
#  'choices': ['efficiency',
#   'getting work done',
#   'marriage',
#   'finishing up',
#   'results'],
#  'answer': 'marriage',
#  'abstractive_explanation': 'the term bride and groom is mostly associated with a marriage ceremony',
#  'extractive_explanation': 'bride and groom'}

# %%
def calculate_metrics_cose(folder_name, model_name, size):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    perturbation_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/perturbation"
    gradient_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/gradient"

    batch_size = 10
    ext = '.parquet'

    for batch_start in tqdm(range(0, size, batch_size)):
        file_name = f'/batch_{batch_start}'
        evidence_batch = cose['extractive_explanation'][batch_start: batch_start + batch_size]

        for current_folder in [perturbation_folder, gradient_folder]:
            save_path = current_folder + file_name + '_metrics' + ext

            if os.path.exists(save_path):
                print(f"Skipping {save_path}, already exists.")
                continue

            current_batch = pd.read_parquet(current_folder + file_name + ext)

            precisions = []
            weight_recalls = []
            f1_tokens = []
            jaccards = []
            span_hit_recalls = []

            for i in range(batch_size):
                evidence = [evidence_batch[i]]
                text = f"Premise: {current_batch['question']} Hypothesis: The answer is {current_batch['correct_answer']}"

                spans = find_token_spans(text=text, evidence_list=evidence, tokenizer=tokenizer)
                token_positions = current_batch['token_positions'][i]
                weights = current_batch['weights'][i]

                precision_ = precision(spans, token_positions)
                weight_recall_ = weight_recall(spans, weights, token_positions)
                f1_ = f1_token(spans, weights, token_positions)
                jaccard_ = jaccard_similarity(spans, token_positions)
                span_hit_ = span_hit_recall(spans, token_positions)

                precisions.append(precision_)
                weight_recalls.append(weight_recall_)
                f1_tokens.append(f1_)
                jaccards.append(jaccard_)
                span_hit_recalls.append(span_hit_)

            results = pd.DataFrame({
                'precision': precisions,
                'weight_recall': weight_recalls,
                'f1_token': f1_tokens,
                'jaccard_similarity': jaccards,
                'span_hit_recall': span_hit_recalls
            })

            results.to_parquet(save_path)

def get_results_cose(folder_name, model_name, size):
    perturbation_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/perturbation"
    gradient_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/gradient"
    results = pd.DataFrame(columns=['precision', 'weight_recall', 'f1_token', 'jaccard_similarity', 'span_hit_recall', 'method'])

    for batch_start in range(0, size, batch_size):
        file_name = f'/batch_{batch_start}'

        for current_folder in [perturbation_folder, gradient_folder]:
            save_path = current_folder + file_name + '_metrics' + ext
            data = pd.read_parquet(save_path)
            data['method'] = current_folder.split('/')[-1]
            results = pd.concat([results, data])
    print(model_name, size)
    display(results.groupby('method').agg('mean'))

# %%
folder_name = 'bert_cos'
model_name = "roberta-large-mnli"
size = 500

calculate_metrics_cose(folder_name, model_name, size)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
get_results_cose(folder_name, model_name, size)
# Out:
# /tmp/ipython-input-10-68669817.py:70: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, data])
# roberta-large-mnli 500
#               precision  weight_recall  f1_token  jaccard_similarity  \
# method
# gradient       0.006798       0.006187  0.006442            0.005026
# perturbation   0.006597       0.005315  0.005618            0.004848
#
#               span_hit_recall
# method
# gradient                0.030
# perturbation            0.028

# %%
def calculate_metrics_cose(folder_name, model_name, size):
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    perturbation_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/perturbation"

    batch_size = 10
    ext = '.parquet'

    for batch_start in tqdm(range(0, size, batch_size)):
        file_name = f'/batch_{batch_start}'
        evidence_batch = cose['extractive_explanation'][batch_start: batch_start + batch_size]

        for current_folder in [perturbation_folder]:
            save_path = current_folder + file_name + '_metrics' + ext

            if os.path.exists(save_path):
                print(f"Skipping {save_path}, already exists.")
                continue

            current_batch = pd.read_parquet(current_folder + file_name + ext)

            precisions = []
            weight_recalls = []
            f1_tokens = []
            jaccards = []
            span_hit_recalls = []

            for i in range(batch_size):
                evidence = [evidence_batch[i]]
                text = f"Premise: {current_batch['question']} Hypothesis: The answer is {current_batch['correct_answer']}"

                spans = find_token_spans(text=text, evidence_list=evidence, tokenizer=tokenizer)
                token_positions = current_batch['token_positions'][i]
                weights = current_batch['weights'][i]

                precision_ = precision(spans, token_positions)
                weight_recall_ = weight_recall(spans, weights, token_positions)
                f1_ = f1_token(spans, weights, token_positions)
                jaccard_ = jaccard_similarity(spans, token_positions)
                span_hit_ = span_hit_recall(spans, token_positions)

                precisions.append(precision_)
                weight_recalls.append(weight_recall_)
                f1_tokens.append(f1_)
                jaccards.append(jaccard_)
                span_hit_recalls.append(span_hit_)

            results = pd.DataFrame({
                'precision': precisions,
                'weight_recall': weight_recalls,
                'f1_token': f1_tokens,
                'jaccard_similarity': jaccards,
                'span_hit_recall': span_hit_recalls
            })

            results.to_parquet(save_path)

def get_results_cose(folder_name, model_name, size):
    perturbation_folder = f"/content/drive/MyDrive/NLP_project/{folder_name}/results/perturbation"
    results = pd.DataFrame(columns=['precision', 'weight_recall', 'f1_token', 'jaccard_similarity', 'span_hit_recall', 'method'])

    for batch_start in range(0, size, batch_size):
        file_name = f'/batch_{batch_start}'

        for current_folder in [perturbation_folder]:
            save_path = current_folder + file_name + '_metrics' + ext
            data = pd.read_parquet(save_path)
            data['method'] = current_folder.split('/')[-1]
            results = pd.concat([results, data])
    print(model_name, size)
    display(results.groupby('method').agg('mean'))

# %%
folder_name = 'deberta_cos'
model_name = "bert-base-uncased"
size = 500

calculate_metrics_cose(folder_name, model_name, size)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
get_results_cose(folder_name, model_name, size)
# Out:
# /tmp/ipython-input-17-2117904251.py:68: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, data])
# bert-base-uncased 500
#               precision  weight_recall  f1_token  jaccard_similarity  \
# method
# perturbation   0.009109       0.009526  0.009273            0.007297
#
#               span_hit_recall
# method
# perturbation            0.036
